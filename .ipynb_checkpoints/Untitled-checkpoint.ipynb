# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_file = 'AMZN.csv.'
data = pd.read_csv(data_file, header=None)

# %%
data
# Out:
#      0            1
# 0    1   266.489990
# 1    2   253.809998
# 2    3   269.200012
# 3    4   277.690002
# 4    5   301.220001
# 5    6   280.980011
# 6    7   312.640015
# 7    8   364.029999
# 8    9   393.619995
# 9   10   398.790009
# 10  11   358.690002
# 11  12   362.100006
# 12  13   336.369995
# 13  14   304.130005
# 14  15   312.549988
# 15  16   324.779999
# 16  17   312.989990
# 17  18   339.040009
# 18  19   322.440002
# 19  20   305.459991
# 20  21   338.640015
# 21  22   310.350006
# 22  23   354.529999
# 23  24   380.160004
# 24  25   372.100006
# 25  26   421.779999
# 26  27   429.230011
# 27  28   434.089996
# 28  29   536.150024
# 29  30   512.890015
# 30  31   511.890015
# 31  32   625.900024
# 32  33   664.799988
# 33  34   675.890015
# 34  35   587.000000
# 35  36   552.520020
# 36  37   593.640015
# 37  38   659.590027
# 38  39   722.789978
# 39  40   715.619995
# 40  41   758.809998
# 41  42   769.159973
# 42  43   837.309998
# 43  44   789.820007
# 44  45   750.570007
# 45  46   768.659973
# 46  47   823.479980
# 47  48   845.039978
# 48  49   886.539978
# 49  50   924.989990
# 50  51   994.619995
# 51  52   968.000000
# 52  53   987.780029
# 53  54   980.599976
# 54  55   961.349976
# 55  56  1105.280029
# 56  57  1176.750000
# 57  58  1169.469971
# 58  59  1450.890015
# 59  60  1521.949951

# %%
x = data.iloc[:, 0].values
y = data.iloc[:, 1].values

# %%
def fun_obj(B, x, y, n):
    return np.mean((y-np.array([x**i for i in range(n+1)]).T.dot(B))**2)

# %%
import scipy.optimize as opt

# %%
B01 = np.zeros(2)
ajuste1 = opt.minimize(fun_obj, B01, args=(x,y,1))
B02 = np.zeros(3)
ajuste2 = opt.minimize(fun_obj, B02, args=(x,y,2))
B03 = np.zeros(4)
ajuste3 = opt.minimize(fun_obj, B03, args=(x,y,3))

# %%
yhat1 = ajuste1.x[0]+ajuste1.x[1]*x
yhat2 = ajuste2.x[0]+ajuste2.x[1]*x+ajuste2.x[2]*x**2
yhat3 = ajuste3.x[0]+ajuste3.x[1]*x+ajuste3.x[2]*x**2+ajuste3.x[3]*x**3

plt.figure(figsize=(8,6))
plt.plot(x, y, label = 'datos reales')
plt.plot(x, yhat1, label = 'ajuste 1')
plt.plot(x, yhat2, label = 'ajuste 2')
plt.plot(x, yhat3, label = 'ajuste 3')
plt.xlabel('meses')
plt.ylabel('Precio de cierre')
plt.legend(loc='best')
plt.show()

# %%
error1 = np.mean((y-yhat1)**2)
error2 = np.mean((y-yhat2)**2)
error3 = np.mean((y-yhat3)**2)

plt.figure(figsize=(8,6))
plt.plot([1,2,3],[ems1,ems2,ems3], 'o')
plt.xlabel('orden del polinomio')
plt.ylabel('error cuadrático')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e7d7bcb08c96> in <module>()
#       4
#       5 plt.figure(figsize=(8,6))
# ----> 6 plt.plot([1,2,3],[ems1,ems2,ems3], 'o')
#       7 plt.xlabel('orden del polinomio')
#       8 plt.ylabel('error cuadrático')
#
# NameError: name 'ems1' is not defined
